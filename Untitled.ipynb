# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/solmipark/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/solmipark/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/solmipark/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/solmipark/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/solmipark/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/solmipark/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/overrides.py:6
#       4 import os
# ----> 6 from numpy.core._multiarray_umath import (
#       7     add_docstring, implement_array_function, _get_implementing_args)
#       8 from numpy.compat._inspect import getargspec
#
# ImportError: dlopen(/Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/_multiarray_umath.cpython-311-darwin.so, 0x0002): Library not loaded: @rpath/libopenblas.0.dylib
#   Referenced from: <D861DA83-9FCD-3D45-95C4-C308B540214C> /Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/_multiarray_umath.cpython-311-darwin.so
#   Reason: tried: '/Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/../../../../libopenblas.0.dylib' (no such file), '/Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/../../../../libopenblas.0.dylib' (no such file), '/Users/solmipark/anaconda3/bin/../lib/libopenblas.0.dylib' (no such file), '/Users/solmipark/anaconda3/bin/../lib/libopenblas.0.dylib' (no such file), '/usr/local/lib/libopenblas.0.dylib' (no such file), '/usr/lib/libopenblas.0.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/__init__.py:141
#     138 # Allow distributors to run custom init code
#     139 from . import _distributor_init
# --> 141 from . import core
#     142 from .core import *
#     143 from . import compat
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/__init__.py:49
#      25     import sys
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#      51     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.11 from "/Users/solmipark/anaconda3/bin/python"
#   * The NumPy version is: "1.24.3"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/_multiarray_umath.cpython-311-darwin.so, 0x0002): Library not loaded: @rpath/libopenblas.0.dylib
#   Referenced from: <D861DA83-9FCD-3D45-95C4-C308B540214C> /Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/_multiarray_umath.cpython-311-darwin.so
#   Reason: tried: '/Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/../../../../libopenblas.0.dylib' (no such file), '/Users/solmipark/anaconda3/lib/python3.11/site-packages/numpy/core/../../../../libopenblas.0.dylib' (no such file), '/Users/solmipark/anaconda3/bin/../lib/libopenblas.0.dylib' (no such file), '/Users/solmipark/anaconda3/bin/../lib/libopenblas.0.dylib' (no such file), '/usr/local/lib/libopenblas.0.dylib' (no such file), '/usr/lib/libopenblas.0.dylib' (no such file, not in dyld cache)

# %%
def merge_excel_sheets(file_path):
    # 엑셀 파일의 모든 시트 이름 가져오기
    xls = pd.ExcelFile(file_path)
    sheet_names = xls.sheet_names
    
    # 모든 시트를 읽어서 하나의 데이터 프레임으로 합치기
    df_list = []
    for sheet in sheet_names:
        df = pd.read_excel(file_path, sheet_name=sheet)
        df_list.append(df)
    
    # 데이터 프레임 리스트를 하나로 합치기
    combined_df = pd.concat(df_list, ignore_index=True)
    
    return combined_df

# 엑셀 파일 경로
file_path = 'path_to_your_excel_file.xlsx'

# 함수 호출
combined_df = merge_excel_sheets(file_path)

# 결과 확인
combined_df.head()
